# %%
import os
import pandas as pd

# %%
os.listdir()
# Out:
# ['ARS.py',
#  'SwabRegistrationForm_20211027_DRESORT.xlsx',
#  'test.ipynb',
#  'test.py']

# %%
df = pd.read_excel('SwabRegistrationForm_20211027_DRESORT.xlsx', skiprows=7)

# %%
df.shape
# Out:
# (23, 20)

# %%
df.columns
# Out:
# Index(['Registration Station *', 'Identification Number *',
#        'Full Name (as in ID) ', 'Date of Birth (YYYYMMDD) ', 'Gender (M/F) *',
#        'Nationality', 'Postal Code', 'Street Name', 'Level No', 'Unit No',
#        'Time (24hr Format HH:mm) *', 'Contact No ', 'Disposition *', 'BatchId',
#        'UTM No.', 'Status(S=Attended, R=Rejected) *',
#        'Reason (Must include when Status is R, max character length is 255)',
#        'Special Ops Notes (Max character length is 255)', 'ID Type *',
#        'Country of Issue *'],
#       dtype='object')

# %%
df = df.sort_values('Unit No')

# %%
df.columns
# Out:
# Index(['Registration Station *', 'Identification Number *',
#        'Full Name (as in ID) ', 'Date of Birth (YYYYMMDD) ', 'Gender (M/F) *',
#        'Nationality', 'Postal Code', 'Street Name', 'Level No', 'Unit No',
#        'Time (24hr Format HH:mm) *', 'Contact No ', 'Disposition *', 'BatchId',
#        'UTM No.', 'Status(S=Attended, R=Rejected) *',
#        'Reason (Must include when Status is R, max character length is 255)',
#        'Special Ops Notes (Max character length is 255)', 'ID Type *',
#        'Country of Issue *'],
#       dtype='object')

# %%
df['Identification Number *'].values.tolist()
# Out:
# ['S1262237F',
#  'G2041753L',
#  'T0537061I',
#  'S7918254J',
#  'G6743955X',
#  'S8136070G',
#  'T0534389A',
#  'S7620985E',
#  'S9233939D',
#  'T1402665C',
#  'S8670719E',
#  'S8372343B',
#  'S9111114D',
#  'T0107808E',
#  'S8531291Z',
#  'G8241042U',
#  'G1646912U',
#  'S8034939D',
#  'S8818428I',
#  'T0207155F',
#  'S7021670A',
#  'F2331271U',
#  'S1745814J']

# %%
df
# Out:
#     Registration Station * Identification Number *  \
# 15                     NaN               S1262237F
# 11                     NaN               G2041753L
# 4                      NaN               T0537061I
# 21                     NaN               S7918254J
# 12                     NaN               G6743955X
# 22                     NaN               S8136070G
# 8                      NaN               T0534389A
# 2                      NaN               S7620985E
# 10                     NaN               S9233939D
# 13                     NaN               T1402665C
# 14                     NaN               S8670719E
# 20                     NaN               S8372343B
# 18                     NaN               S9111114D
# 19                     NaN               T0107808E
# 17                     NaN               S8531291Z
# 16                     NaN               G8241042U
# 5                      NaN               G1646912U
# ...
